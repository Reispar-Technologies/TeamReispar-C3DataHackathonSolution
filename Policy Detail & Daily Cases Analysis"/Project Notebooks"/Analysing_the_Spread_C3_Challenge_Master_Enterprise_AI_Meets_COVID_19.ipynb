# %% [markdown]
# # C3. Challenge Enterprise AI Meets COVID-19

# %% [markdown]
# ---
#
# **Run All code in "Collecting data sets being published..." to retrieve data.**
#
# ---

# %% [markdown]
# ## Collecting data sets being published (collapse from table of contents after runing)

# %% [markdown]
# Data can be accessed from the blog:
#
# https://c3.ai/blog/enterprise-ai-meets-covid-19/

# %%
cd ..
# Out:
# /

# %%
cd content/
# Out:
# /content

# %%
mkdir Alldata

# %%
cd Alldata
# Out:
# /content/Alldata

# %%
mkdir 01_Johns_Hopkins_COVID-19_Data_Repository

# %%
cd 01_Johns_Hopkins_COVID-19_Data_Repository
# Out:
# /content/Alldata/01_Johns_Hopkins_COVID-19_Data_Repository

# %%
#get Johns Hopkins University: COVID-19 Data Repository
# !git clone https://github.com/CSSEGISandData/COVID-19.git
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 64770 (delta 20), reused 29 (delta 16), pack-reused 64734
# Receiving objects: 100% (64770/64770), 553.31 MiB | 20.90 MiB/s, done.
# Resolving deltas: 100% (41564/41564), done.
# Checking out files: 100% (742/742), done.

# %%
cd ..
# Out:
# /content/Alldata

# %%
mkdir 02_COVID_Tracking_Project

# %%
cd 02_COVID_Tracking_Project
# Out:
# /content/Alldata/02_COVID_Tracking_Project

# %%
# !wget https://covidtracking.com/data/download/all-states-history.csv
# Out:
# --2020-11-14 15:47:35--  https://covidtracking.com/data/download/all-states-history.csv
# Resolving covidtracking.com (covidtracking.com)... 157.230.37.202, 206.189.89.118, 2400:6180:0:d1::4df:d001, ...
# Connecting to covidtracking.com (covidtracking.com)|157.230.37.202|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1892001 (1.8M) [text/csv]
# Saving to: ‘all-states-history.csv’
#
# all-states-history. 100%[===================>]   1.80M   334KB/s    in 5.7s
#
# 2020-11-14 15:47:41 (326 KB/s) - ‘all-states-history.csv’ saved [1892001/1892001]

# %%
# !wget https://covidtracking.com/data/download/national-history.csv
# Out:
# --2020-11-14 15:47:41--  https://covidtracking.com/data/download/national-history.csv
# Resolving covidtracking.com (covidtracking.com)... 157.230.37.202, 206.189.89.118, 2400:6180:0:d1::360:1001, ...
# Connecting to covidtracking.com (covidtracking.com)|157.230.37.202|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31183 (30K) [text/csv]
# Saving to: ‘national-history.csv’
#
# national-history.cs 100%[===================>]  30.45K  --.-KB/s    in 0.04s
#
# 2020-11-14 15:47:42 (735 KB/s) - ‘national-history.csv’ saved [31183/31183]

# %%
cd ..
# Out:
# /content/Alldata

# %%
mkdir 03_NYC_COVID-19_Data

# %%
cd 03_NYC_COVID-19_Data
# Out:
# /content/Alldata/03_NYC_COVID-19_Data

# %%
# !git clone https://github.com/nytimes/covid-19-data.git
# Out:
# Cloning into 'covid-19-data'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 7351 (delta 5), reused 12 (delta 2), pack-reused 7336
# Receiving objects: 100% (7351/7351), 282.44 MiB | 15.14 MiB/s, done.
# Resolving deltas: 100% (4498/4498), done.

# %%
cd ..
# Out:
# /content/Alldata

# %%
mkdir 04_nCoV-2019_Epidemiology_Data

# %%
cd 04_nCoV-2019_Epidemiology_Data
# Out:
# /content/Alldata/04_nCoV-2019_Epidemiology_Data

# %%
# !wget https://raw.githubusercontent.com/beoutbreakprepared/nCoV2019/master/latest_data/latestdata.tar.gz
# Out:
# --2020-11-14 15:48:31--  https://raw.githubusercontent.com/beoutbreakprepared/nCoV2019/master/latest_data/latestdata.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16036062 (15M) [application/octet-stream]
# Saving to: ‘latestdata.tar.gz’
#
# latestdata.tar.gz   100%[===================>]  15.29M  38.9MB/s    in 0.4s
#
# 2020-11-14 15:48:32 (38.9 MB/s) - ‘latestdata.tar.gz’ saved [16036062/16036062]

# %%
# !tar -xvf 'latestdata.tar.gz'
# Out:
# latestdata.csv

# %%
cd ..
# Out:
# /content/Alldata

# %%
mkdir 05_Empty_MOBS_Lab_COVID-19_Situation_Report

# %%
mkdir 06_Empty_WHO_Daily_Situation_Report

# %%
mkdir 07_Empty_European_CDC_Worldwide_Situation_Updates

# %%
mkdir 08_U_of_Montreal_COVID-19_Image_Data_Collection

# %%
cd 08_U_of_Montreal_COVID-19_Image_Data_Collection
# Out:
# /content/Alldata/08_U_of_Montreal_COVID-19_Image_Data_Collection

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 3614 (delta 7), reused 11 (delta 5), pack-reused 3599
# Receiving objects: 100% (3614/3614), 633.00 MiB | 20.16 MiB/s, done.
# Resolving deltas: 100% (1430/1430), done.
# Checking out files: 100% (1173/1173), done.

# %%
cd ..
# Out:
# /content/Alldata

# %%
mkdir 09_Empty_NCBI_Virus_Database_National_Center_for_Biotechnology_Information

# %%
mkdir 10_COVID-19_Open_Research_Dataset

# %%
cd 10_COVID-19_Open_Research_Dataset
# Out:
# /content/Alldata/10_COVID-19_Open_Research_Dataset

# %%
#Go to Your Account and click on Create New API Token. A file named kaggle.json
#will get downloaded containing your username and token key
#this file needed to be uploaded to this folder
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/Alldata/10_COVID-19_Open_Research_Dataset" 
# !kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /content/Alldata/10_COVID-19_Open_Research_Dataset. Or use the environment method.

# %%
cd ..
# Out:
# /content/Alldata

# %%
mkdir 11_Empty_AWS_COVID-19_Data_Lake

# %%
mkdir 12_Empty_Google_BigQuery_COVID-19_Dataset

# %% [markdown]
# ## Date sets Istructions & Empty Date sets links

# %% [markdown]
# All from the blog post: **Enterprise AI Meets COVID-19** By **Thomas M. Siebel**
#
# https://c3.ai/blog/enterprise-ai-meets-covid-19/
#
#
# ---
#
# Many organizations publish COVID-19 related data sets in the public domain to fuel COVID-19 Enterprise AI efforts. Some notable recent efforts include:
#
# <li><a href="https://github.com/CSSEGISandData/COVID-19" rel="noopener noreferrer" target="_blank">1_Johns Hopkins University: COVID-19 Data Repository</a></li>
#
#     github repository included in the folder
#
# <li><a href="https://covidtracking.com/" rel="noopener noreferrer" target="_blank">2_The COVID Tracking Project</a></li>
#
#     Two csv file included in folder.
# * [go_to_download_page](https://covidtracking.com/data/download)
#
# ---
#
# <li><a href="https://github.com/nytimes/covid-19-data" rel="noopener noreferrer" target="_blank">3_The New York Times: COVID-19 Data in the United States</a></li>
#
#     github repository included in the folder
#
# <li><a href="https://github.com/beoutbreakprepared/nCoV2019/tree/master/latest_data" rel="noopener noreferrer" target="_blank">4_nCoV-2019 Data Working Group: Epidemiology Data</a></li>
#
#     csv file included in folder
#
# <li><a href="https://www.mobs-lab.org/2019ncov.html" rel="noopener noreferrer" target="_blank">5_MOBS Lab: COVID-19 Situation Report</a></li>
#
#     No download page found
#     Analysis of the COVID-19 Epidemic graphs
#     can be used for Idea generating
#
# <li><a href="https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports" rel="noopener noreferrer" target="_blank">6_World Health Organization: Daily Situation Reports</a></li>
#
#     No download page found
#     Analysis of the COVID-19 Epidemic graphs
#     can be used for Idea generating
#
#
# <li><a href="https://www.ecdc.europa.eu/en/covid-19-pandemic" rel="noopener noreferrer" target="_blank">7_European Centre for Disease Prevention and Control: Worldwide Situation Updates</a></li>
#
#     No download page found
#     Analysis of the COVID-19 Epidemic graphs
#     can be used for Idea generating
#
# <li><a href="https://github.com/ieee8023/covid-chestxray-dataset" rel="noopener noreferrer" target="_blank">8_University of Montreal: COVID-19 Image Data Collection</a></li>
#
#     github repository included in the folder
#
# <li><a href="https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus?SeqType_s=Nucleotide&amp;VirusLineage_ss=Severe%20acute%20respiratory%20syndrome%20coronavirus%202,%20taxid:2697049" rel="noopener noreferrer" target="_blank">9_National Center for Biotechnology Information Virus Database</a></li>
#
#     csv file need to manually doanload from:
# * [direct download](https://www.ncbi.nlm.nih.gov/genomes/VirusVariation/vvsearch2/?fq=%7B!tag=SeqType_s%7DSeqType_s:(%22Nucleotide%22)&fq=VirusLineageId_ss:(2697049)&cmd=download&sort=SourceDB_s%20desc,CreateDate_dt%20desc,id%20asc&dlfmt=csv&fl=Accession:id,SRA_Accession:SRALink_ss,Release_Date:CreateDate_dt,Species:VirusSpecies_s,Genus:VirusGenus_s,Family:VirusFamily_s,Length:SLen_i,Sequence_Type:SourceDB_s,Nuc_Completeness:Completeness_s,Genotype:Serotype_s,Segment:Segment_s,Authors:Authors_csv,Publications:PubMed_csv,Geo_Location:CountryFull_s,USA:USAState_s,Host:Host_s,Isolation_Source:Isolation_csv,Collection_Date:CollectionDate_s,BioSample:BioSample_s,GenBank_Title:Definition_s)
# * [go_to_download_page](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus?SeqType_s=Nucleotide&VirusLineage_ss=Severe%20acute%20respiratory%20syndrome%20coronavirus%202,%20taxid:2697049)
#
#
# ---
#
#
# <li><a href="https://registry.opendata.aws/cord-19/" rel="noopener noreferrer" target="_blank">10_COVID-19 Open Research Dataset (CORD-19)</a></li>
#
#     20GB Data set from Kaggle
#     download instruction:
#     1. Go to Your Account and click on Create New API Token. A file named kaggle.json
#     2. will get downloaded containing your username and token key
#     3. this file needed to be uploaded to this folder "/content/Alldata/10_COVID-19_Open_Research_Dataset"
#     after that move to this directory and implement below:
#
#     import os
#     os.environ['KAGGLE_CONFIG_DIR'] = "/content/Alldata/10_COVID-19_Open_Research_Dataset"
#     !kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge
#
#     zip file will be downloaded
#
#     to unzip use:(it will take some time)
#
#     !unzip \*.zip  && rm *.zip
#
#     this will unzipping all zip files then deleting all zip files
#
# <li><a href="https://dj2taa9i652rf.cloudfront.net/" rel="noopener noreferrer" target="_blank">11_The AWS COVID-19 Data Lake</a></li>
#
#     Data Lake need to go and dive exploring!!...
#
# <li><a href="https://console.cloud.google.com/marketplace/details/bigquery-public-datasets/covid19-public-data-program?_ga=2.150880692.-38085877.1586877794&amp;pli=1" rel="noopener noreferrer" target="_blank">12_Google BigQuery COVID-19 Dataset</a></li>
#
#     Data Lake need to go and dive exploring!!...
#
#
# <li><a href="https://c3.ai/covid/" rel="noopener noreferrer" target="_blank">C3 AI COVID-19 Data Lake</a></li>

# %% [markdown]
# ---
#
#
# Ripe avenues for impactful breakthroughs from AI include but are not limited to:(Added to shared below points)
#
# - Biomedical informatics methods for drug design and repurposing
# - Modeling, simulation, and prediction of COVID-19 propagation
# - Efficacy of COVID-19 interventions
#
# Tolulade- Additional areas
# - 1. Analysis to identify locations with highest hit to prevent additional spread
# - 2.  Analytics to predict possible/potential covid19 victim (preventive health-care) (using tempareture or additional parameteres
# - 3. Investigate datasets to uncover hidden insights regarding victims of covid19 that could aid in epidemiological research and treatment purposes
# - 4. Design of an IoT sensored data based monitoring system that helps or IoT device that pings an alert on Covid19 patients or potenial patient or location
# - 5. Real time collaborative platform that helps healthcare facilities, clinics, share insights and analytics on medications, therapies, and interventions.
#
#
# Added:
# - 6. improve already acheived report with updated larger scale data (need your ideas to improve)
# - 7. check tracking data and the effeciency of intervention actions (both NYC-COVID & nCOV)
# - 8. website to offer CT image scan diagnose processing with accurecy percetage

# %% [markdown]
# ---
#
# Projects may address but are not limited to: - we get to pick one or two of these
#
# -  Applying machine learning/AI methods to mitigate the spread of COVID-19
# -  Genome-specific COVID-19 medical protocols, including precision medicine of host responses
# -  Biomedical informatics methods for drug design and repurposing existing therapies
# -  Design and sharing of clinical trials for collecting and analyzing data on medications, therapies, and interventions
# -  Modeling, simulation, prediction of COVID-19 propagation and efficacy of interventions
# -  Logistics and optimization analysis for design of public health strategies and interventions
# -  Rigorous approaches to designing sampling and testing strategies
# -  Data analytics for COVID-19 research harnessing private and sensitive data, including the role of edge computing/IoT for gathering data
# - Improving societal resilience in response to the spread of the pandemic
# -  Broader efforts in biomedicine, infectious disease modeling, response logistics and optimization, public health, tools, and methodologies around the containment of infectious diseases, and response to pandemics so as to be better prepared for future infectious disease response.

# %% [markdown]
# ---
# Let the journey begins!! ...  :)
#
# ---

# %% [markdown]
# #Sections for Each Team member

# %% [markdown]
# ## Section_3_Tolulade

# %% [markdown]
# ### Data Preparation & Data Processing
# #### Project / Sub Section Goal:
# Make a forceast of Covid19 data by location looking for disparity and the prevalent hidden insight (differentiaotr) and how cases my be reduced or solved by understanding locations with fewer cases.
#
# This could help in;
#
# Identifying Covi19 cases
# Predicting Covid19 cases
# Preventing or Curing Covid19 cases
# The first thing i want to do in this project is prepare my datasets for analytics. The data from the John Hopkins Git isn't processed.
#
# In the first stage my data output will have these columns;
#
# Confirmed, Deaths, Recovered and Active are cumulative data.
# New cases, New deaths and New Recovered are day wise data.
# This DataFrames is ordered by Date and Country/Region.
#
# First Data Source (Available on C3 Data Lake):
# https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series -John Hopkins Time Series Real Time
#
# Let's pull out our time series data which is also avialbe via the **project colab directory**. /content/Alldata/01_Johns_Hopkins_COVID-19_Data_Repository/COVID-19/csse_covid_19_data/csse_covid_19_time_series

# %% [markdown]
# Step One:
# Let's Download, load, merge, clean and aggregate COVID-19 data (Global Data)
#
# Confirmed, Recoverd & Deaths

# %%
import pandas as pd
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=39ef56c8e1da779b3e472a33c687055ad144f17d4f819754ea5ec1d0f320f179
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
import wget

# %%
# url of the raw csv dataset
urls = ['https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv', 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv', 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv']
[wget.download(url) for url in urls]
# Out:
# ['time_series_covid19_confirmed_global.csv',
#  'time_series_covid19_deaths_global.csv',
#  'time_series_covid19_recovered_global.csv']

# %% [markdown]
# Let's Load & extract data list in our time series data

# %%
confirmed_df = pd.read_csv('time_series_covid19_confirmed_global.csv') 
death_df = pd.read_csv('time_series_covid19_deaths_global.csv')
recovered_df = pd.read_csv('time_series_covid19_recovered_global.csv')

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  11/11/20  11/12/20  11/13/20
# 0            NaN    Afghanistan  33.93911  ...     42609     42795     42969
# 1            NaN        Albania  41.15330  ...     25801     26211     26701
# 2            NaN        Algeria  28.03390  ...     64257     65108     65975
# 3            NaN        Andorra  42.50630  ...      5567      5616      5725
# 4            NaN         Angola -11.20270  ...     12953     13053     13228
#
# [5 rows x 301 columns]

# %%
death_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  11/11/20  11/12/20  11/13/20
# 0            NaN    Afghanistan  33.93911  ...      1581      1591      1595
# 1            NaN        Albania  41.15330  ...       590       598       605
# 2            NaN        Algeria  28.03390  ...      2093      2111      2124
# 3            NaN        Andorra  42.50630  ...        75        75        75
# 4            NaN         Angola -11.20270  ...       312       315       317
#
# [5 rows x 301 columns]

# %%
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  11/11/20  11/12/20  11/13/20
# 0            NaN    Afghanistan  33.93911  ...     34967     35024     35036
# 1            NaN        Albania  41.15330  ...     12493     12574     12667
# 2            NaN        Algeria  28.03390  ...     42980     42980     43779
# 3            NaN        Andorra  42.50630  ...      4488      4585      4675
# 4            NaN         Angola -11.20270  ...      6125      6250      6326
#
# [5 rows x 301 columns]

# %%
confirmed_df.columns
death_df.columns
recovered_df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '11/4/20', '11/5/20', '11/6/20', '11/7/20', '11/8/20', '11/9/20',
#        '11/10/20', '11/11/20', '11/12/20', '11/13/20'],
#       dtype='object', length=301)

# %%
confirmed_df.columns[4:]
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '11/4/20', '11/5/20', '11/6/20', '11/7/20', '11/8/20', '11/9/20',
#        '11/10/20', '11/11/20', '11/12/20', '11/13/20'],
#       dtype='object', length=297)

# %% [markdown]
# So we merge Confirmed, Deaths & Recovered

# %% [markdown]
# Using melt() to unpivot DataFrames from current wide format into long format. We are transposing all date columns into values.
#
# Use ‘Province/State’, ‘Country/Region’, ‘Lat’, ‘Long’ as identifier variables. They will later be used for merging.
#
# Unpivot date columns (As we saw previously columns[4:]) with variable column ‘Date’ and value column ‘Confirmed’

# %%
dates = confirmed_df.columns[4:]
confirmed_df_long = confirmed_df.melt(
    id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], 
    value_vars=dates, 
    var_name='Date', 
    value_name='Confirmed'
)
death_df_long = death_df.melt(
    id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], 
    value_vars=dates, 
    var_name='Date', 
    value_name='Deaths'
)
recovered_df_long = recovered_df.melt(
    id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], 
    value_vars=dates, 
    var_name='Date', 
    value_name='Recovered'
)

# %%
confirmed_df_long
# Out:
#       Province/State      Country/Region  ...      Date  Confirmed
# 0                NaN         Afghanistan  ...   1/22/20          0
# 1                NaN             Albania  ...   1/22/20          0
# 2                NaN             Algeria  ...   1/22/20          0
# 3                NaN             Andorra  ...   1/22/20          0
# 4                NaN              Angola  ...   1/22/20          0
# ...              ...                 ...  ...       ...        ...
# 79888            NaN  West Bank and Gaza  ...  11/13/20      61514
# 79889            NaN      Western Sahara  ...  11/13/20         10
# 79890            NaN               Yemen  ...  11/13/20       2072
# 79891            NaN              Zambia  ...  11/13/20      17093
# 79892            NaN            Zimbabwe  ...  11/13/20       8765
#
# [79893 rows x 6 columns]

# %%
death_df_long
# Out:
#       Province/State      Country/Region  ...      Date  Deaths
# 0                NaN         Afghanistan  ...   1/22/20       0
# 1                NaN             Albania  ...   1/22/20       0
# 2                NaN             Algeria  ...   1/22/20       0
# 3                NaN             Andorra  ...   1/22/20       0
# 4                NaN              Angola  ...   1/22/20       0
# ...              ...                 ...  ...       ...     ...
# 79888            NaN  West Bank and Gaza  ...  11/13/20     548
# 79889            NaN      Western Sahara  ...  11/13/20       1
# 79890            NaN               Yemen  ...  11/13/20     605
# 79891            NaN              Zambia  ...  11/13/20     350
# 79892            NaN            Zimbabwe  ...  11/13/20     257
#
# [79893 rows x 6 columns]

# %%
recovered_df_long
# Out:
#       Province/State      Country/Region  ...      Date  Recovered
# 0                NaN         Afghanistan  ...   1/22/20          0
# 1                NaN             Albania  ...   1/22/20          0
# 2                NaN             Algeria  ...   1/22/20          0
# 3                NaN             Andorra  ...   1/22/20          0
# 4                NaN              Angola  ...   1/22/20          0
# ...              ...                 ...  ...       ...        ...
# 76027            NaN  West Bank and Gaza  ...  11/13/20      53367
# 76028            NaN      Western Sahara  ...  11/13/20          8
# 76029            NaN               Yemen  ...  11/13/20       1394
# 76030            NaN              Zambia  ...  11/13/20      16134
# 76031            NaN            Zimbabwe  ...  11/13/20       8090
#
# [76032 rows x 6 columns]

# %% [markdown]
# Note

# %% [markdown]
# We have to remove recovered data for Canada due to mismatch issue (Canada recovered data is counted by Country-wise rather than Province/State-wise).
#
# After which we merge the 3 data frames

# %%
recovered_df_long = recovered_df_long[recovered_df_long['Country/Region']!='Canada']

# %%
# Merging confirmed_df_long and death_df_long
full_table = confirmed_df_long.merge(
  right=death_df_long, 
  how='left',
  on=['Province/State', 'Country/Region', 'Date', 'Lat', 'Long']
)
# Merging full_table and recovered_df_long
full_table = full_table.merge(
  right=recovered_df_long, 
  how='left',
  on=['Province/State', 'Country/Region', 'Date', 'Lat', 'Long']
)

# %%
full_table
# Out:
#       Province/State      Country/Region  ...  Deaths  Recovered
# 0                NaN         Afghanistan  ...       0        0.0
# 1                NaN             Albania  ...       0        0.0
# 2                NaN             Algeria  ...       0        0.0
# 3                NaN             Andorra  ...       0        0.0
# 4                NaN              Angola  ...       0        0.0
# ...              ...                 ...  ...     ...        ...
# 79888            NaN  West Bank and Gaza  ...     548    53367.0
# 79889            NaN      Western Sahara  ...       1        8.0
# 79890            NaN               Yemen  ...     605     1394.0
# 79891            NaN              Zambia  ...     350    16134.0
# 79892            NaN            Zimbabwe  ...     257     8090.0
#
# [79893 rows x 8 columns]

# %% [markdown]
# ### Data Cleaning
#
# We are going to;
#
# Convert Date from string to datetime
# Replace missing value NaN
# Coronavirus cases reported from 3 cruise ships should be treated differently
# You probably already notice that the values in the new Date column are all string with m/dd/yy format. To convert Date values from string to datetime, let’s use DataFrame.to_datetime()

# %%
full_table['Date'] = pd.to_datetime(full_table['Date'])

# %%
full_table
# Out:
#       Province/State      Country/Region  ...  Deaths  Recovered
# 0                NaN         Afghanistan  ...       0        0.0
# 1                NaN             Albania  ...       0        0.0
# 2                NaN             Algeria  ...       0        0.0
# 3                NaN             Andorra  ...       0        0.0
# 4                NaN              Angola  ...       0        0.0
# ...              ...                 ...  ...     ...        ...
# 79888            NaN  West Bank and Gaza  ...     548    53367.0
# 79889            NaN      Western Sahara  ...       1        8.0
# 79890            NaN               Yemen  ...     605     1394.0
# 79891            NaN              Zambia  ...     350    16134.0
# 79892            NaN            Zimbabwe  ...     257     8090.0
#
# [79893 rows x 8 columns]

# %% [markdown]
# Finding Missing Values
#
# Missing values NaN can be detected by running full_table.isna().sum()

# %%
full_table.isna().sum()
# Out:
# Province/State    55836
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered          5643
# dtype: int64

# %% [markdown]
# We found a lot NaN in Province/State, which is reasonabale as many countries only report the Country-wise data. However, there are 5,301 NaNs in Recovered (as at 3:07pm WAT- 27th Oct, 2020) and let’s replace them with 0 as well as the 8,928 NaNs in Deaths

# %%
full_table['Recovered'] = full_table['Recovered'].fillna(0)

# %%
full_table['Deaths'] = full_table['Deaths'].fillna(0)

# %%
full_table.isna().sum()
# Out:
# Province/State    55836
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# dtype: int64

# %% [markdown]
# Note
# Apart from missing values, there are coronavirus cases reported from 3 cruise ships: Grand Princess, Diamond Princess and MS Zaandam. These data need to be extracted and treated differently due to Province/State and Country/Region mismatch over time.

# %%
# extract the ship data
ship_rows = full_table['Province/State'].str.contains('Grand Princess') | full_table['Province/State'].str.contains('Diamond Princess') | full_table['Country/Region'].str.contains('Diamond Princess') | full_table['Country/Region'].str.contains('MS Zaandam')
full_ship = full_table[ship_rows]

# %%
#  Let's get rid of ship data from full_table
full_table = full_table[~(ship_rows)]

# %% [markdown]
# ### Data Aggregation
# So all our Confirmed, Deaths, Recovered are existing data from raw CSV dataset. We will be adding active cases
#
# Let’s add an active cases column. Active, which is calculated by active = confirmed — deaths — recovered.

# %%
# Active Case = confirmed - deaths - recovered
full_table['Active'] = full_table['Confirmed'] - full_table['Deaths'] - full_table['Recovered']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
full_table
# Out:
#       Province/State      Country/Region        Lat  ...  Deaths Recovered  Active
# 0                NaN         Afghanistan  33.939110  ...       0       0.0     0.0
# 1                NaN             Albania  41.153300  ...       0       0.0     0.0
# 2                NaN             Algeria  28.033900  ...       0       0.0     0.0
# 3                NaN             Andorra  42.506300  ...       0       0.0     0.0
# 4                NaN              Angola -11.202700  ...       0       0.0     0.0
# ...              ...                 ...        ...  ...     ...       ...     ...
# 79888            NaN  West Bank and Gaza  31.952200  ...     548   53367.0  7599.0
# 79889            NaN      Western Sahara  24.215500  ...       1       8.0     1.0
# 79890            NaN               Yemen  15.552727  ...     605    1394.0    73.0
# 79891            NaN              Zambia -13.133897  ...     350   16134.0   609.0
# ...

# %% [markdown]
# Next, let’s aggregate data into **Country/Region** wise and group them by Date and Country/Region.
#
#
#
# *   sum() is to get the total count of ‘Confirmed’, ‘Deaths’, ‘Recovered’, ‘Active’ for the given Date and Country/Region.
# *   reset_index() reset the index and use the default one, which is Date and Country/Region.

# %%
full_grouped = full_table.groupby(['Date', 'Country/Region'])['Confirmed', 'Deaths', 'Recovered', 'Active'].sum().reset_index()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
full_grouped
# Out:
#             Date      Country/Region  Confirmed  Deaths  Recovered  Active
# 0     2020-01-22         Afghanistan          0       0        0.0     0.0
# 1     2020-01-22             Albania          0       0        0.0     0.0
# 2     2020-01-22             Algeria          0       0        0.0     0.0
# 3     2020-01-22             Andorra          0       0        0.0     0.0
# 4     2020-01-22              Angola          0       0        0.0     0.0
# ...          ...                 ...        ...     ...        ...     ...
# 56128 2020-11-13  West Bank and Gaza      61514     548    53367.0  7599.0
# 56129 2020-11-13      Western Sahara         10       1        8.0     1.0
# 56130 2020-11-13               Yemen       2072     605     1394.0    73.0
# 56131 2020-11-13              Zambia      17093     350    16134.0   609.0
# 56132 2020-11-13            Zimbabwe       8765     257     8090.0   418.0
#
# [56133 rows x 6 columns]

# %% [markdown]
# Let’s add Day wise **New cases, New deaths and New recovered** by deducting the corresponding accumulative data on the previous day.

# %%
import numpy as np

# %%
# new cases 
temp = full_grouped.groupby(['Country/Region', 'Date', ])['Confirmed', 'Deaths', 'Recovered']
temp = temp.sum().diff().reset_index()
mask = temp['Country/Region'] != temp['Country/Region'].shift(1)
temp.loc[mask, 'Confirmed'] = np.nan
temp.loc[mask, 'Deaths'] = np.nan
temp.loc[mask, 'Recovered'] = np.nan
# renaming columns
temp.columns = ['Country/Region', 'Date', 'New cases', 'New deaths', 'New recovered']
# merging new values
full_grouped = pd.merge(full_grouped, temp, on=['Country/Region', 'Date'])
# filling na with 0
full_grouped = full_grouped.fillna(0)
# fixing data types
cols = ['New cases', 'New deaths', 'New recovered']
full_grouped[cols] = full_grouped[cols].astype('int')
# 
full_grouped['New cases'] = full_grouped['New cases'].apply(lambda x: 0 if x<0 else x)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ### Note
# Finally here is the full_grouped. Please note that this final output is Country-wise data with Confirmed, Deaths, Recovered and Active are cumulative data.
#
# New cases, New deaths and New Recovered are day wise data. This DataFrames is ordered by Date and Country/Region.

# %%
full_grouped
# Out:
#             Date      Country/Region  ...  New deaths  New recovered
# 0     2020-01-22         Afghanistan  ...           0              0
# 1     2020-01-22             Albania  ...           0              0
# 2     2020-01-22             Algeria  ...           0              0
# 3     2020-01-22             Andorra  ...           0              0
# 4     2020-01-22              Angola  ...           0              0
# ...          ...                 ...  ...         ...            ...
# 56128 2020-11-13  West Bank and Gaza  ...           6            506
# 56129 2020-11-13      Western Sahara  ...           0              0
# 56130 2020-11-13               Yemen  ...           0              0
# 56131 2020-11-13              Zambia  ...           0             32
# 56132 2020-11-13            Zimbabwe  ...           2             30
#
# [56133 rows x 9 columns]

# %%
# Let's save this final data to a CSV file:
full_grouped.to_csv('COVID-19-time-series-JHU-clean-complete.csv')

# %% [markdown]
# ### Some Correlation analysis
#
# Correlation Analysis & Feature Selection We are going to show Linear relationship between two variables
#
# 1. **+1** means *Strongest possible agreement *(things are equal, correlated)
# 2. **0** means Strongest possible disagreement (no relationship)
# 3. -**1** means opposite (negative correlation)

# %%
full_grouped.corr()
# Out:
#                Confirmed    Deaths  ...  New deaths  New recovered
# Confirmed       1.000000  0.912271  ...    0.590312       0.706602
# Deaths          0.912271  1.000000  ...    0.654429       0.590631
# Recovered       0.922302  0.778995  ...    0.511189       0.743938
# Active          0.816553  0.828769  ...    0.524984       0.440339
# New cases       0.832968  0.772321  ...    0.728091       0.751291
# New deaths      0.590312  0.654429  ...    1.000000       0.565296
# New recovered   0.706602  0.590631  ...    0.565296       1.000000
#
# [7 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,16)) 
sns.heatmap(full_grouped.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Data Exploration - Let's Investigate our Data JHU

# %%
import pandas as pd
import altair as alt
# !pip install altair vega_datasets

# %% [markdown]
# ### Let's Show A total Daily Case in USA
# (US as seen in the dataset)

# %%
full_grouped = pd.read_csv('COVID-19-time-series-JHU-clean-complete.csv', parse_dates=['Date'])

# %%
US = full_grouped[full_grouped['Country/Region'] == 'US']

# %% [markdown]
# ### We Create a base chart with the common elements

# %%
base = alt.Chart(US).mark_bar().encode(
    x='monthdate(Date):O',
).properties(
    width=600
)

# %% [markdown]
# After this, let's **concatenate** horizontally using the | operator
#
# Showing *Total and Confirmed Cases with Death *overtime in the USA

# %%
hex = alt.value("#DB1435")
base.encode(y='Confirmed').properties(title='Total Confirmed') | base.encode(y='Deaths', color=hex).properties(title='Total Deaths')
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# Let's concatenate horizontally using the | operator
#
# Showing **Daily New Cases & Daily Newly Recoverd & Daily New Deaths** overtime in the USA

# %%
hex = alt.value("#DB1435") 
recx = alt.value("#25EA0E") 
base.encode(y='New cases').properties(title='Daily New Cases') | base.encode(y='New recovered', color=recx).properties(title='Daily New Recovered') | base.encode(y='New deaths', color=hex).properties(title='Daily New Deaths')
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ### Let's Analyse the Spread.
#
# First, let’s import the libraries, load data and select a list of countries
#
# We will be analysing the ***top 6 countries*** and the **least 5 countries** of the Covid19 cases. (as at time of this investigation Tuesday October 27th, 2020
#
# Bases on the table from https://covid19.reispartechnologies.com.ng
#
# ## Top 6 countries with the highest confirmed cases and deaths are;
# 1. USA
# 2. India
# 3. Brazil
# 4. Russia
# 5. Spain
# 6. Argentina
#
#
#
# ##Least 5 Countries with confirmed least cases starting from New Zealand and below include;
# 1. New Zealnad
# 2. Chad
# 3. Liberia
# 4. Niger
# 5. Vietnam

# %% [markdown]
# First, we will import the libraries, load data and select a list of countries

# %%
import pandas as pd
import altair as alt
full_grouped = pd.read_csv('COVID-19-time-series-JHU-clean-complete.csv', parse_dates=['Date'])
countries = ['US', 'India', 'Brazil', 'Russia', 'Spain', 'Argentina', 'New Zealand', 'Chad', 'Liberia', 'Niger', 'Vietnam']
selected_countries = full_grouped[full_grouped['Country/Region'].isin(countries)]

# %%
selected_countries
# Out:
#        Unnamed: 0       Date  ... New deaths  New recovered
# 6               6 2020-01-22  ...          0              0
# 23             23 2020-01-22  ...          0              0
# 34             34 2020-01-22  ...          0              0
# 78             78 2020-01-22  ...          0              0
# 98             98 2020-01-22  ...          0              0
# ...           ...        ...  ...        ...            ...
# 56068       56068 2020-11-13  ...          0              1
# 56083       56083 2020-11-13  ...        401          18388
# 56102       56102 2020-11-13  ...        308              0
# 56118       56118 2020-11-13  ...       1431          43890
# 56127       56127 2020-11-13  ...          0              8
#
# [3267 rows x 10 columns]

# %% [markdown]
# #### Chart shows these countries
#
#
# 1. USA
# 2. India
# 3. Brazil
# 4. Russia
# 5. Spain
# 6. Argentina
#
#
# 1. New Zealnad
# 2. Chad
# 3. Liberia
# 4. Niger
# 5. Vietnam

# %% [markdown]
# #### Let’s create a circle chart to display the day-wise New cases

# %%
alt.Chart(selected_countries).mark_circle().encode(
    x='monthdate(Date):O',
    y='Country/Region',
    color='Country/Region',
    size=alt.Size('New cases:Q',
        scale=alt.Scale(range=[0, 1000]),
        legend=alt.Legend(title='Daily new cases')
    ) 
).properties(
    width=800,
    height=300
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Let’s create a circle chart to display tthe Total Recoverd in the selected countries

# %%
alt.Chart(selected_countries).mark_circle().encode(
    x='monthdate(Date):O',
    y='Country/Region',
    color='Country/Region',
    size=alt.Size('Recovered:Q',
        scale=alt.Scale(range=[0, 1000]),
        legend=alt.Legend(title='Total Recovered')
    ) 
).properties(
    width=800,
    height=300
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Conuntries Back to Lockdown (2nd Wave) & Taiwan Difference
#
# First, we are going to **analyse** some of the countries who flung back to Lockdown mode due to the surge of Covid19 as at November 2nd, 2020, Time: 7:07 am WAT
#
# **Sources:**
#
# Belgium, France, Germany, England
# https://news.sky.com/story/coronavirus-lockdowns-return-across-europe-heres-what-you-need-to-know-12117280
#
# Ireland
# https://www.politico.eu/article/ireland-coronavirus-lockdown-six-weeks/
#
# Czech
# https://apnews.com/article/virus-outbreak-czech-republic-prague-andrej-babis-8c1a05d3280ae8b6cd773b8e9fc952f3
#
#
# ## Selected countries which we are looking at are;
# 1. Germany
# 2. France
# 3. Belgium
# 4. Ireland
# 5. Czech
# 6. UK
#
#
#
# ## Taiwan
# Taiwan goes 200 days without any local case. Let's understand the situation by analysing their data.
#
# https://www.bloomberg.com/amp/news/articles/2020-10-29/this-place-hasn-t-had-a-local-coronavirus-case-in-200-days?__twitter_impression=true

# %% [markdown]
# ### Let's Show A total Daily Case across Germany- UK

# %%
import pandas as pd
import altair as alt
full_grouped = pd.read_csv('COVID-19-time-series-JHU-clean-complete.csv', parse_dates=['Date'])
countries = ['Germany', 'France', 'Belgium', 'Ireland', 'Czechia', 'Taiwan*', 'United Kingdom']
Bselected_countries = full_grouped[full_grouped['Country/Region'].isin(countries)]

# %%
Bselected_countries
# Out:
#        Unnamed: 0       Date  ... New deaths  New recovered
# 16             16 2020-01-22  ...          0              0
# 46             46 2020-01-22  ...          0              0
# 61             61 2020-01-22  ...          0              0
# 65             65 2020-01-22  ...          0              0
# 82             82 2020-01-22  ...          0              0
# ...           ...        ...  ...        ...            ...
# 56005       56005 2020-11-13  ...          1            548
# 56009       56009 2020-11-13  ...        188          13705
# 56026       56026 2020-11-13  ...          7              0
# 56109       56109 2020-11-13  ...          0              1
# 56122       56122 2020-11-13  ...        376             58
#
# [2079 rows x 10 columns]

# %%
Germany = full_grouped[full_grouped['Country/Region'] == 'Germany']
France = full_grouped[full_grouped['Country/Region'] == 'France']
Belgium = full_grouped[full_grouped['Country/Region'] == 'Belgium']
Czechia = full_grouped[full_grouped['Country/Region'] == 'Czechia']
UK = full_grouped[full_grouped['Country/Region'] == 'United Kingdom']
Ireland = full_grouped[full_grouped['Country/Region'] == 'Ireland']
Taiwan = full_grouped[full_grouped['Country/Region'] == 'Taiwan*']

# %% [markdown]
# ### Numerical data distribution
#
# For this part lets look at the distribution of all of **the features** *(of the selected countries in our John Hopksins Data)* by ploting them
#
# To do so lets first list all the types of our data from our dataset and take **only the numerical ones**: I want to include the data column

# %%
jk = Bselected_countries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
list(set(jk.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('O'), dtype('int64'), dtype('<M8[ns]')]

# %%
jk_num = jk.select_dtypes(include = ['float64', 'int64', '<M8[ns]'])
jk_num.head()
# Out:
#     Unnamed: 0       Date  Confirmed  ...  New cases  New deaths  New recovered
# 16          16 2020-01-22          0  ...          0           0              0
# 46          46 2020-01-22          0  ...          0           0              0
# 61          61 2020-01-22          0  ...          0           0              0
# 65          65 2020-01-22          0  ...          0           0              0
# 82          82 2020-01-22          0  ...          0           0              0
#
# [5 rows x 9 columns]

# %%
jk_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %% [markdown]
# ### Correlation
#
# Now we'll try to find which features are strongly **correlated with New Cases. We'll store them in a var called golden_features_list. We'll reuse our df_num dataset to do so.**

# %%
jk_num_corr = jk_num.corr()['New cases'][:-3] # -1 because the 3rd latest row is New cases
golden_features_list = jk_num_corr[abs(jk_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with New cases:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 2 strongly correlated values with New cases:
# Confirmed    0.734343
# Active       0.725650
# Name: New cases, dtype: float64

# %% [markdown]
# ### Note -We can draw that from the above
#
# People with virus are infecting others.
#
# Now have a list of **strongly correlated** values but this list is incomplete as we know that correlation is affected by outliers. So we could proceed as follow:
#
# a. Plot the numerical features and see which ones have very few or explainable outliers.
#
# b. Remove the outliers from these features and see which one can have a good correlation without their outliers
#
# Btw, correlation by itself does not always explain the relationship between data so ploting them could even lead us to new insights and in the same manner. correlated values have a linear relationship.
#
# For example, relationships such as curvilinear relationship cannot be guessed just by looking at the correlation value so lets take the features we excluded from our correlation table and plot them to see if they show some kind of pattern.

# %%
for i in range(0, len(jk_num.columns), 5):
    sns.pairplot(data=jk_num,
                x_vars=jk_num.columns[i:i+5],
                y_vars=['New cases'])

# %% [markdown]
# We can clearly identify some relationships. Most of them seems to have a scattered relationship with the SalePrice and if we look closely at the data we can see that a lot of data points are located on x = 0 which may indicate the absence of such feature in the BSelected data set.
#
#
#
# Let's try to remove these 0 values and repeat the process of finding correlated values:

# %%
import operator

individual_features_df = []
for i in range(0, len(jk_num.columns) - 3): 
    tmpDf = jk_num[[jk_num.columns[i], 'New cases']]
    tmpDf = tmpDf[tmpDf[jk_num.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['New cases'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
#       Recovered: 0.24907200130905588
#      Unnamed: 0: 0.36377366251102394
#          Deaths: 0.37014909178692557
#          Active: 0.7234142655278681
#       Confirmed: 0.7327077125792265
#            Date:             1.0

# %% [markdown]
# It still varifies that till date both active and confirmed cases are  correlated when we cleaned up the data a bit. Now our golden_features_list var looks like this:

# %%
golden_features_list = [key for key, value in all_correlations if abs(value) >= 0.5]
print("There is {} strongly correlated values with New cases:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 3 strongly correlated values with New cases:
# ['Active', 'Confirmed', 'Date']
